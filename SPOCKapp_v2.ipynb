# %%
# %%HTML
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
# CELL 1
import warnings
warnings.filterwarnings('ignore')
from astropy.utils import iers
#iers.conf.auto_download = False 
from astroplan import Observer
from astropy.coordinates import SkyCoord,EarthLocation,CartesianRepresentation
from astropy.time import Time
from astropy import units as u
from astropy.utils import iers
import datetime
import emoji
from IPython.display import HTML, display, clear_output, Javascript
from IPython.display import Image
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual, Layout, Button, Box, HTML, TwoByTwoLayout, GridspecLayout
import matplotlib.pyplot as plt
import markdown 
import numpy as np
import os
import pandas as pd
from plotly import graph_objs as go
from colorama import Fore
from SPOCK import target_list_from_stargate_path
import SPOCK.stats as SPOCKstats
import SPOCK.long_term_scheduler as SPOCKLT
import SPOCK.short_term_scheduler as SPOCKST
import SPOCK.plots_scheduler as SPOCKplot
from SPOCK.make_night_plans import offset_target_position
from SPOCK import target_list_from_stargate_path
import sys
import time
import yaml


pd.options.display.max_rows = 2000
pd.options.display.max_columns = 80

iers.IERS_A_URL  ='ftp://cddis.gsfc.nasa.gov/pub/products/iers/finals2000A.all'

# %matplotlib notebook


#from astroplan import download_IERS_A
#download_IERS_A

#check_user = widgets.Text(description='Username',style=style)
#check_password = widgets.Password(description='Password',style=style)

#credentials = widgets.HBox([check_user,check_password],layout=widgets.Layout(height='40px'))
#display(credentials)
# Out:
# INFO:  Please add password.csv file in: /Users/ed268546/Dropbox/Mac/Documents/codes/SPOCK_v2/SPOCK/credentials/
# INFO:  OK Password file exists
# INFO: Latest target list already updated.
# INFO: Target list already in good format
# "ltr" dir="ltr" lang="en-GB">
#
# Archive down for maintenance
# "X-UA-Compatible" content="IE=edge" />
#
# "UTF-8" />
#
# Archive down for maintenance
# "initial-scale=1.0, width=device-width" name="viewport" />
#
# "Cache-Control" content="no-cache, no-store, must-revalidate">
#
# "Pragma" content="no-cache">
#
# "Expires" content="0">
#
# "refresh" content="60" /> -->
#
# "icon"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/favicon.ico" />
#
# Archive down for maintenance
# "apple-touch-icon-precomposed"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-precomposed.png" />
#
# Archive down for maintenance
# Archive down for maintenance
# "apple-touch-icon-precomposed" sizes="72x72"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-72x72-precomposed.png" />
#
# Archive down for maintenance
# "apple-touch-icon-precomposed" sizes="76x76"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-76x76-precomposed.png" />
#
# Archive down for maintenance
# "apple-touch-icon-precomposed" sizes="114x114"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-114x114-precomposed.png" />
#
# Archive down for maintenance
# "apple-touch-icon-precomposed" sizes="120x120"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-120x120-precomposed.png" />
#
# Archive down for maintenance
# "apple-touch-icon-precomposed" sizes="144x144"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-144x144-precomposed.png" />
#
# Archive down for maintenance
# "apple-touch-icon-precomposed" sizes="152x152"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-152x152-precomposed.png" />
#
# Archive down for maintenance
# "apple-touch-icon-precomposed" sizes="180x180"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-180x180-precomposed.png" />
#
# Archive down for maintenance
# "icon" sizes="180x180"
#
# "https://www.cosmos.esa.int/o/CosmosTheme-theme/images/apple-touch-icon-180x180-precomposed.png" />
#
# "text/css" rel="stylesheet" href="/gaia/html_page_resources/css/esdc.css">
#
# "text/css" rel="stylesheet" href="/gaia/html_page_resources/css/gacs.css">
#
# "text/css" rel="stylesheet" href="/gaia/html_page_resources/css/style.css">
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# r;i[r]=i[r]||function(){
#
# i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#
# s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# "position: absolute; z-index: -32767; top: -20cm; width: 10cm; height: 10cm; visibility: hidden;"aria-hidden="true"></div>
#
# "position: absolute; left: 0px; top: 0px; right: 0px; bottom: 0px; display: block;">
#
# "position: absolute; left: 0px; top: 0px; right: 0px; bottom: 0px;">
#
# "position: absolute; z-index: -32767; top: -20ex; width: 10em; height: 10ex; visibility: hidden;"aria-hidden="true">
#
# Archive down for maintenance
# "position: absolute; overflow: hidden; left: 0px; top: 0px; right: 0px; height: 120px;">
#
# "position: absolute; left: 0px; top: 0px; right: 0px; bottom: 0px;">
#
# "height: 14px; width: 100%; border-spacing: 0; border-collapse: collapse;" >
#
# Archive down for maintenance
# Archive down for maintenance
# "left" style="vertical-align: top; padding: 0px">
#
# "esdc_tb">
#
# Archive down for maintenance
# "esdc_top_sep"><img class="gwt-Image"
#
# "1" height="20" src="/gaia/html_page_resources/images/top_sep.gif"
#
# "height: 14px; width: 2px;"></img></li>
#
# "esdc_external">
#
# "esdch4">
#
# "_blank" href="http://www.esa.int"> <span>
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# "esdc_external">
#
# "esdch4">
#
# "http://www.esa.int/About_Us/ESAC" target="_blank">About
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# "left" style="vertical-align: top; padding: 0px;"></td>
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# "esdc_top-title" style="height: 100px">
#
# "title" style="position: absolute; z-index: 2;">gaia archive (OPER)</div>
#
# "http://www.esa.int">
#
# "height: 100px; width: 851px; overflow: hidden; background: url('/gaia/html_page_resources/images/header-cosmos-gaia.png') no-repeat scroll 0px 0px transparent; position: absolute; top: 20px; right: 0px; z-index: 1;" />
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# "esdc_tb"
#
# "position: absolute; overflow: hidden; left: 0px; right: 0px; bottom: 0px; height: 20px;">
#
# "float: right; margin: 0 0px 0 0;">
#
# Archive down for maintenance
# "esdch4">Copyright 2000 - 2020 © European Space
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# "position: absolute; overflow: visible; top: 120px; bottom: 30px; left: 0px; right: 0px;">
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# "content.html" width="100%" height="100%" seamless style="border: none"></iframe-->
#
# "display: inline-block; position: fixed; top: 0; bottom: 0; left: 0; right: 0; width: 1024px; height: 600px; margin: auto; overflow: auto"-->
#
# Archive down for maintenance
# "top: 0; bottom: 0; left: 0; right: 0; width: 100%; height: 100%; margin:auto; overflow auto">-->
#
# Archive down for maintenance
# "top: 0; bottom: 0; left: 0; right: 0; width: 100%; height: 100%; margin: auto; overflow: auto">
#
# "portlet-column portlet-column-only span12" id="column-1" style="margin: 20px 100px 20px 100px">
#
# "portlet-dropzone portlet-column-content portlet-column-content-only" id="layout-column_column-1">
#
# "portlet-boundary portlet-boundary_56_ portlet-static portlet-static-end portlet-borderless portlet-journal-content " id="p_p_id_56_INSTANCE_zChxaDZZCLJR_">
#
# "p_56_INSTANCE_zChxaDZZCLJR"></span>
#
# "portlet-borderless-container">
#
# "portlet-body">
#
# "journal-content-article">
#
# "DR2background">
#
# "padding:3%">
#
# "https://www.cosmos.esa.int/web/gaia" target="_self">
#
# "" src="https://www.cosmos.esa.int/documents/29201/29227/gaia_RGB_transparent_gif.gif/3bf5526a-3e81-4ce4-a648-0ac1f5bbd8ef?t=1378282536449" style="width: 100px; height: 59px; float: left;">
#
# Archive down for maintenance
# "http://gea.esac.esa.int/archive/" target="_blank">
#
# "" src="https://www.cosmos.esa.int/documents/29201/29222/Gaia+Archive+logo.png/167275a5-9577-4d20-b0e0-a97625a73e0b?t=1469109633000" style="float: right;" width="60" height="59">
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# "DataReleaseCountDown" style="text-align: center;color:#FFFFFF;">&nbsp;&nbsp;</h2> <p>&nbsp;</p>
#
# "text-align: center;">
#
# "color: rgb(137 8 8);font-size:30px;">Maintenance ongoing!</span>
#
# Archive down for maintenance
# "color: rgb(114,4,4);font-size:18px;">Our system is down for maintenance activities. Meanwhile, the Gaia data is accessible via our bulk-download repository (<a href="http://cdn.gea.esac.esa.int/Gaia/" target="_blank">http://cdn.gea.esac.esa.int/Gaia/</a>) - see our tutorial (<a href="https://www.cosmos.esa.int/web/gaia-users/archive/extract-data#bulk_download" target="_blank">https://www.cosmos.esa.int/web/gaia-users/archive/extract-data#bulk_download</a>) for more information - and via our partner and affiliated data centres (<a href="https://www.cosmos.esa.int/web/gaia/data-access#PartnerDataCentres" target="_blank">https://www.cosmos.esa.int/web/gaia/data-access#PartnerDataCentres</a>).</span><br/><br/><br/><br/>
#
# "color: rgb(114,4,4);font-size:16px;">
#
# "https://www.cosmos.esa.int/web/gaia-users/archive">Gaia's tutorials and help information</a>,
#
# "https://www.cosmos.esa.int/web/gaia"> Gaia's resources for the scientific community</a>
#
# "https://www.cosmos.esa.int/web/gaia/data-access#PartnerDataCentres">Gaia data from partner data centres</a>
#
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance
# Archive down for maintenance

# %%
# CELL 2

style = {'description_width':'initial'}


# ------------- LONG_TERM SCHEDULER ------------- 
observatory_widget = widgets.Combobox(
    # value='John',
    placeholder='Choose site',
    options=['SSO', 'SNO', 'Saint-Ex', 'TS_La_Silla','TN_Oukaimeden'],
    description='Site:',
    ensure_option=True,
    disabled=False)

telescope_widget = widgets.Combobox(
    # value='John',
    placeholder='SSO telescope',
    options=['Io','Europa','Ganymede','Callisto'],
    description='Telescope:',
    ensure_option=True,
    disabled=False)

operator_widget = widgets.Combobox(
    # value='John',
    placeholder='Opertor for TS/TN',
    options=['Manu','Youssef','Fran','Khalid','Marin'],
    description='Operator:',
    ensure_option=True,
    disabled=False)

start_date_widget =widgets.DatePicker(
    description='Start date',
    disabled=False)

end_date_widget =widgets.DatePicker(
    description='End date',
    disabled=False)

input_file_widget = widgets.Text(description='File',placeholder='input.csv')

run_widget = widgets.Button(
    value=False,
    description='Click me',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check')

run_widget_mangos = widgets.Button(
    value=False,
    description=emoji.emojize('predict :mango:'),
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check')

gotosave_widget = widgets.Button(
    value=False,
    description='Go to save',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check')

gotomake_widget = widgets.Button(
    value=False,
    description='Go to make',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check')

gotoupload_widget = widgets.Button(
    value=False,
    description='Go to upload',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check')

gotoall_widget = widgets.Button(
    value=False,
    description='Go to all together',
    layout=Layout(width='20%', height='30px'),
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    style= {'button_color':'lightsteelblue'},
    tooltip='Description  ',
    icon='check')

manual_prediction_widget = widgets.Button(
    value=False,
    description='Predict',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Description',
    icon='check')

# ------------- SHORT_TERM SCHEDULER ------------- 

short_term_option_widget = widgets.Combobox(
    # value='John',
    placeholder='Choose option',
    options=['Follow-up','Special target with known start/end time',\
             'Special target (observe the most we can)','MANGOS','Dome rotation','Monitoring'],
    description='What kind? :',
    ensure_option=True,
    disabled=False)

short_day_widget =widgets.DatePicker(
    description='Day ',
    disabled=False)

short_start_time_widget = widgets.Text(description='Start time',placeholder='2020-01-16 23:00:00')
short_end_time_widget = widgets.Text(description='End time',placeholder='2020-01-17 03:00:00')

start_time_widget =widgets.DatePicker(
    description='Start Time',
    disabled=False)

end_time_widget =widgets.DatePicker(
    description='End Time',
    disabled=False)

#input_file_special_widget = widgets.Text(description='File',placeholder='input_short_term.csv')
 
input_target_list_widget = widgets.Text(description='File',
                                        placeholder=target_list_from_stargate_path)

schedules_st = SPOCKST.Schedules()
schedules_st.load_parameters()
schedules_mangos = SPOCKST.Schedules()
schedules_mangos.load_parameters(mangos=True)

    
target_widget = widgets.Combobox(
    # value='John',
    placeholder='Spxxx-xxxx',
    options=list(pd.read_csv(target_list_from_stargate_path,delimiter=',')['Sp_ID']), 
    description='Target name:',
    ensure_option=True,
    disabled=False)

target_special_widget = widgets.Combobox(
    # value='John',
    placeholder='Trappist-1x',
    options=list(schedules_st.target_table_spc['Sp_ID']), 
    description='Target special:',
    ensure_option=True,
    disabled=False)

target_follow_up_widget = widgets.Combobox(
    # value='John',
    placeholder='Trappist-1x',
    options=list(schedules_st.target_table_spc_follow_up['Sp_ID']), 
    description='Target follow-up:',
    ensure_option=True,
    disabled=False)

target_follow_up_mangos = widgets.Combobox(
    # value='John',
    placeholder='TOI-xxx',
    options=list(schedules_mangos.target_table_spc_follow_up['Sp_ID']), 
    description='MANGOs follow-up:',
    ensure_option=True,
    disabled=False)

plot_option_widget = widgets.Combobox(
    # value='John',
    placeholder='Choose a plot option',
    options=['Gant chart','Visibility plot SPECULOOS','Visibility plot follow-up',
             'Visibility plot special', 'Phase coverage','Global gant chart'],
    description='What kind? :',
    ensure_option=True,
    disabled=False)

#check_a_target_widget = widgets.Button(value=False,description='Select a target',disabled=False,
#        button_style='info',tooltip='show target list',icon='fa-arrow-right')

check_np_widget = widgets.Button(
    value=False,
    description='See night plans',
    disabled=False,
    button_style='info', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click to see night plans',
    icon='check')

info_target_widget = widgets.Button(
    value=False,
    description='Info on a target',
    disabled=False,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click to chose target',
    icon='check')


def run_all(b): 
    display(Javascript('Jupyter.notebook.execute_cells([3])'))
    
def run_button_mangos(b): 
    display(Javascript('Jupyter.notebook.execute_cells([3])'))
    
def run_gotosave(b): 
    display(Javascript('Jupyter.notebook.execute_cells([7])'))
def run_gotomake(b): 
    display(Javascript('Jupyter.notebook.execute_cells([9])'))
def run_gotoupload(b): 
    display(Javascript('Jupyter.notebook.execute_cells([11])'))
    
def run_manual_predict(b):
    display(Javascript('Jupyter.notebook.execute_cells([21])'))

# ----------------------------------------------------------- #
    
long_term_tab = widgets.Accordion(children=[widgets.HBox([observatory_widget,telescope_widget,operator_widget]),\
                                        widgets.HBox([start_date_widget,end_date_widget]), run_widget] )
long_term_tab.set_title(0, 'Observatory')
long_term_tab.set_title(1, 'Date range')
long_term_tab.set_title(2, 'Run long term')

# ----------------------------------------------------------- #

short_term_tab = widgets.Accordion(children=[widgets.HBox([observatory_widget,telescope_widget,operator_widget]),\
                                        widgets.VBox([widgets.HBox([short_term_option_widget,short_day_widget]),\
                                        widgets.HBox([short_start_time_widget,short_end_time_widget]),
                                             widgets.HBox([target_special_widget,target_follow_up_widget,
                                                          target_follow_up_mangos])]),
                                             run_widget])
short_term_tab.set_title(0, 'Observatory')
short_term_tab.set_title(1, 'Options')
short_term_tab.set_title(2, 'Run short term')

# ----------------------------------------------------------- #

plot_tab = widgets.Accordion(children=[plot_option_widget,run_widget])
plot_tab.set_title(0, 'Plot option')
plot_tab.set_title(1, 'Run plots')

# ----------------------------------------------------------- #

make_upload_tab = widgets.Accordion(children=[widgets.HBox([observatory_widget,telescope_widget]),\
                                          widgets.HBox([start_date_widget,end_date_widget]),\
                                          widgets.HBox([gotosave_widget,gotomake_widget,gotoupload_widget,\
                                                       gotoall_widget])])
make_upload_tab.set_title(0, 'Site info')
make_upload_tab.set_title(1, 'Date info')
make_upload_tab.set_title(2, 'Go to plan maker and upload')

# ----------------------------------------------------------- #

check_np_tab = widgets.Accordion(children=[check_np_widget])
make_upload_tab.set_title(0, 'Click')

# ----------------------------------------------------------- #

info_target_tab = widgets.Accordion(children=[info_target_widget])
make_upload_tab.set_title(0, 'Click')

# ----------------------------------------------------------- #

ra_text= widgets.FloatText(
    value=346.620833,
    description='RA:',
    disabled=False
)
dec_text =  widgets.FloatText(
    value=-5.0411111,
    description='DEC:',
    disabled=False
)
timing_text =  widgets.FloatText(
    value=2457322.51505,
    description='Timing (BJD):',
    disabled=False
)
period_text =  widgets.FloatText(
    value=1.51088212,
    description='Period (days):',
    disabled=False
)
duration_text =  widgets.FloatText(
    value=0.02511108,
    description='Duration (days):',
    disabled=False
)
name_widget = widgets.Text(description='Target name',placeholder='TOI-XXX')
prediction_date_widget =widgets.DatePicker(
    description='Start date',
    disabled=False)

nb_transits_widget = widgets.IntText(
    value=4,
    description='Nb transits:',
    disabled=False
)

coordinates = TwoByTwoLayout(top_left=ra_text, top_right=dec_text,
                     bottom_left=prediction_date_widget, bottom_right=name_widget)

ephemerids = TwoByTwoLayout(top_left=timing_text, top_right=period_text ,
                     bottom_left=duration_text, bottom_right=nb_transits_widget)

predict_tab = widgets.Accordion(children=[coordinates,ephemerids,manual_prediction_widget,
                                          run_widget])

predict_tab.set_title(0, 'Coordinates')
predict_tab.set_title(1, 'Ephemerids')
predict_tab.set_title(2, 'Run predictions')
predict_tab.set_title(3, 'From WG6 directly')

# ----------------------------------------------------------- #

mango_tab = widgets.Accordion(children=[run_widget_mangos])
mango_tab.set_title(0, 'Predictions MANGOS')


# ----------------------------------------------------------- #
run_widget.on_click(run_all)
run_widget_mangos.on_click(run_button_mangos)
gotosave_widget.on_click(run_gotosave)
gotomake_widget.on_click(run_gotomake)
gotoupload_widget.on_click(run_gotoupload)
gotoall_widget.on_click(run_all)
check_np_widget.on_click(run_all)
info_target_widget.on_click(run_all)

manual_prediction_widget.on_click(run_manual_predict)

tab_nest = widgets.Tab()
tab_nest.children = [long_term_tab, short_term_tab,plot_tab,make_upload_tab,check_np_tab,info_target_tab, predict_tab, mango_tab]
tab_nest.set_title(0, 'Long term scheduler ')
tab_nest.set_title(1, 'Short term scheduler')
tab_nest.set_title(2, 'Plots')
tab_nest.set_title(3, 'Make & Upload only')
tab_nest.set_title(4, 'See night plans')
tab_nest.set_title(5, 'Info on a target')
tab_nest.set_title(6, 'Predictions')
tab_nest.set_title(7, emoji.emojize('Predictions :mango:'))
tab_nest
# Out:
# Tab(children=(Accordion(children=(HBox(children=(Combobox(value='', description='Site:', ensure_option=True, o…

# %%
# CELL 3

if tab_nest.selected_index == 0:
    if observatory_widget.value is '':
        sys.exit('ERROR: You must choose a site')
    if start_date_widget.value is '' and end_date_widget.value is '':
        sys.exit('ERROR: The start and/or end date are not valid')

    start_date = Time(datetime.datetime.strptime(str(start_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
    end_date = Time(datetime.datetime.strptime(str(end_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
    schedule = SPOCKLT.Schedules()
    schedule.observatory_name = observatory_widget.value
    schedule.load_parameters(date_range=[start_date,end_date])
    
    if schedule.observatory_name == 'SSO':
        schedule.telescope = str(telescope_widget.value)
    else:
        schedule.telescope = schedule.observatory_name
    if schedule.observatory_name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        schedule.make_schedule(Altitude_constraint = 28, Moon_constraint = 30)
        display(schedule.target_table_spc[schedule.idx_first_target])
        display(schedule.target_table_spc[schedule.idx_second_target])
        display(Javascript('Jupyter.notebook.execute_cells([13])'))
    else:
        if schedule.observatory_name == 'SNO':
            schedule.telescope = 'Artemis'
        schedule.make_schedule(Altitude_constraint = 25, Moon_constraint = 30)
        display(schedule.target_table_spc[schedule.idx_first_target])
        display(schedule.target_table_spc[schedule.idx_second_target])
        display(Javascript('Jupyter.notebook.execute_cells([13])'))

if tab_nest.selected_index == 1:
    if observatory_widget.value is '':
        sys.exit('ERROR: You must choose a site')
    if short_term_option_widget.value == 'MANGOS':
        schedule = SPOCKST.Schedules()
        schedule.load_parameters(mangos=True)
    else:
        schedule = SPOCKST.Schedules()
        schedule.load_parameters()
    
    if observatory_widget.value == 'SSO':
        schedule.altitude_constraint = 25
        schedule.telescope = str(telescope_widget.value)
    if observatory_widget.value == 'SNO':
        schedule.altitude_constraint = 25
        schedule.telescope = 'Artemis'
    if observatory_widget.value == 'Saint-Ex':
        schedule.altitude_constraint = 28
        schedule.telescope = 'Saint-Ex'
        
    schedule.use = short_term_option_widget.value
    day = Time(datetime.datetime.combine(short_day_widget.value,datetime.time(15,0,0)),format='datetime').iso
    schedule.day_of_night = Time(day)
    
    if short_term_option_widget.value == 'Follow-up':
        if target_follow_up_widget.value != '':
            schedule.observatory_name = observatory_widget.value
            schedule.transit_follow_up(input_name=target_follow_up_widget.value)
        else:
            schedule.observatory_name = observatory_widget.value
            schedule.transit_follow_up()
            
    if short_term_option_widget.value == 'MANGOS':
        if target_follow_up_mangos.value != '':
            schedule.observatory_name = observatory_widget.value
            schedule.transit_follow_up(input_name=target_follow_up_mangos.value)
        else:
            schedule.observatory_name = observatory_widget.value
            schedule.transit_follow_up()

            
    if short_term_option_widget.value == 'Special target with known start/end time':
        start_date = [Time(short_start_time_widget.value).iso]
        end_date = [Time(short_end_time_widget.value).iso]
        schedule.start_end_range = Time([start_date,end_date])
        schedule.observatory_name = observatory_widget.value
        input_name = target_special_widget.value
        schedule.special_target_with_start_end(input_name=input_name)
        
    if short_term_option_widget.value == 'Special target (observe the most we can)':
        input_name = target_special_widget.value
        schedule.observatory_name = observatory_widget.value
        schedule.special_target(input_name=input_name)
        
    if short_term_option_widget.value == 'Dome rotation':
        schedule.dome_rotation()
        
    if short_term_option_widget.value == 'Monitoring':
        start_date = Time(short_start_time_widget.value).iso
        end_date = Time(short_end_time_widget.value).iso
        schedule.start_end_range = Time([start_date,end_date])
        input_name = target_special_widget.value
        schedule.monitoring(input_name,5,61)
        
    display(schedule.SS1_night_blocks)
    
    try:
        schedule.make_scheduled_table()
        schedule.planification()
        schedule.make_night_block()
        display(schedule.scheduled_table_sorted)
        display(Javascript("Jupyter.notebook.execute_cells([13])"))
    except (SystemExit) as e :
        display(Javascript("Jupyter.notebook.execute_cells([4])"))
        print(Fore.YELLOW + 'WARNING: ' + Fore.BLACK + 'No existing night_block for this night or target already scheduled that night')

    #display(Javascript('Jupyter.notebook.execute_cells([6])'))
    
if tab_nest.selected_index == 2:   
    if plot_option_widget.value == 'Visibility plot SPECULOOS':
        display(Javascript('Jupyter.notebook.execute_cells([5])'))
        
    if plot_option_widget.value == 'Visibility plot follow-up':
        display(Javascript('Jupyter.notebook.execute_cells([22])'))
                
    if plot_option_widget.value == 'Visibility plot special':
        display(Javascript('Jupyter.notebook.execute_cells([23])'))
        
    if plot_option_widget.value == 'Phase coverage':
        display(Javascript('Jupyter.notebook.execute_cells([17])'))

    if plot_option_widget.value == 'Global gant chart':
        schedule = SPOCKLT.Schedules()
        schedule.observatory_name = 'SSO'
        schedule.load_parameters(date_range=[start_date,end_date])
        SPOCKplot.gantt_chart_all(schedule.target_list)
        
    if plot_option_widget.value == 'Gant chart':
        display(Javascript("Jupyter.notebook.execute_cells([6])"))

if tab_nest.selected_index == 3:
    if observatory_widget.value is '':
        sys.exit('ERROR: You must choose a site')
    if start_date_widget.value is '' and end_date_widget.value is '':
        sys.exit('ERROR: The start and/or end date are not valid')
    else:
        start_date = Time(datetime.datetime.strptime(str(start_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
        end_date = Time(datetime.datetime.strptime(str(end_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
        schedule = SPOCKLT.Schedules()
        schedule.observatory_name = observatory_widget.value
        schedule.load_parameters(date_range=[start_date,end_date])
        schedule.date_range = Time([start_date,end_date])
        if observatory_widget.value == 'SSO':
            schedule.telescope = str(telescope_widget.value)
    display(Javascript("Jupyter.notebook.execute_cells([13])"))

if tab_nest.selected_index == 4:
    display(Javascript('Jupyter.notebook.execute_cells([18])'))
    
if tab_nest.selected_index == 5:
    display(Javascript('Jupyter.notebook.execute_cells([19])'))
    
if tab_nest.selected_index == 6:
    display(Javascript('Jupyter.notebook.execute_cells([20])'))
    
if tab_nest.selected_index == 7:
    schedules_mangos = SPOCKST.Schedules()
    schedules_mangos.load_parameters(mangos=True)
    display(Javascript('Jupyter.notebook.execute_cells([24])'))
# Out:
# Retrieving planned targets:   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:  No plans in your local file for Io on the 2025-12-01, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-01, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-01, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-01, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-01, looking online to check which targets are observed
# INFO:  Using plans in your local file for Saint-Ex on the 2025-12-01 to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-02, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-02, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-02, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-02, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-02, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-02, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-03, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-03, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-03, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-03, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-03, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-03, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-04, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-04, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-04, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-04, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-04, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-04, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-05, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-05, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-05, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-05, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-05, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-05, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-06, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-06, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-06, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-06, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-06, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-06, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-07, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-07, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-07, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-07, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-07, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-07, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-08, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-08, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-08, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-08, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-08, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-08, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-09, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-09, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-09, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-09, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-09, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-09, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-10, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-10, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-10, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-10, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-10, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-10, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-11, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-11, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-11, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-11, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-11, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-11, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-12, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-12, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-12, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-12, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-12, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-12, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-13, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-13, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-13, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-13, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-13, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-13, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-14, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-14, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-14, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-14, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-14, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-14, looking online to check which targets are observed
# INFO:  No plans in your local file for Io on the 2025-12-15, looking online to check which targets are observed
# INFO:  No plans in your local file for Europa on the 2025-12-15, looking online to check which targets are observed
# INFO:  No plans in your local file for Ganymede on the 2025-12-15, looking online to check which targets are observed
# INFO:  No plans in your local file for Callisto on the 2025-12-15, looking online to check which targets are observed
# INFO:  No plans in your local file for Artemis on the 2025-12-15, looking online to check which targets are observed
# INFO:  No plans in your local file for Saint-Ex on the 2025-12-15, looking online to check which targets are observed
# Scheduling :   0%|          | 0/15 [00:00<?, ?it/s]
# --------------------------
# INFO:  day is :  2025-12-01 15:00:00.000
# --------------------------
# INFO:  Using the existing priority table for this day 2025-12-01
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:  Checking that Sp0700+3157 does not exceed max hours
# total_hours 5.827 h texp 146.44970860428668 s
# INFO:  Checking that Sp0539+4038 does not exceed max hours
# total_hours second target of the night 190.98 h texp 15.066803423441655 s
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0900+2150 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_r_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 170.94 h texp 49.0 s
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0652+4710 does not exceed max hours
# total_hours second target of the night 53.02 h texp 259.9127449631103 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# WARNING:  no second target available
# INFO:  Checking that Sp0807+3213 does not exceed max hours
# total_hours second target of the night 160.59 h texp 35.207726601249135 s
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0516+5640 does not exceed max hours
# total_hours second target of the night 133.82 h texp 15.430334009104037 s
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0741+1738 does not exceed max hours
# total_hours second target of the night 105.9 h texp 31.067775321479644 s
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0011+5908 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 199.74 h texp 13.0 s
# INFO:  First target is 'rise'
#
#
# --------------------------
# INFO:  day is :  2025-12-02 15:00:00.000
# --------------------------
# INFO:  Checking that Sp0700+3157 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours 18.299222222222223 h texp 146.44970860428668 s
# INFO:  Checking that Sp0900+2150 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_r_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 170.94 h texp 49.0 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0652+4710 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 53.02 h texp 259.9127449631103 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0807+3213 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 160.59 h texp 35.207726601249135 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0516+5640 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 133.82 h texp 15.430334009104037 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0741+1738 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 105.9 h texp 31.067775321479644 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0515+5911 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 20.764 h texp 16.355872625164142 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0011+5908 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 212.21222222222224 h texp 13.0 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp0019+5213 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 154.38 h texp 82.88843814284216 s
# INFO:  First target is 'rise'
#
#
# --------------------------
# INFO:  day is :  2025-12-03 15:00:00.000
# --------------------------
# INFO:  Checking that Sp0700+3157 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours 24.543666666666667 h texp 146.44970860428668 s
# INFO:  Checking that Sp0900+2150 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_r_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 170.94 h texp 49.0 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0652+4710 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 53.02 h texp 259.9127449631103 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0807+3213 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 160.59 h texp 35.207726601249135 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0741+1738 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 105.9 h texp 31.067775321479644 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0011+5908 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 212.21222222222224 h texp 13.0 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0515+5911 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 20.764 h texp 16.355872625164142 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0109+2949 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 135.52 h texp 112.80463839127474 s
# INFO:  First target is 'rise'
#
#
# --------------------------
# INFO:  day is :  2025-12-04 15:00:00.000
# --------------------------
# INFO:  Checking that Sp0900+2150 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_r_instrument_system_response.csv` has been generated and saved!
# total_hours 170.94 h texp 49.0 s
# INFO:  Checking that Sp0807+3213 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 160.59 h texp 35.207726601249135 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0741+1738 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 105.9 h texp 31.067775321479644 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0109+2949 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 141.77 h texp 112.80463839127474 s
# INFO:  First target is 'rise'
#
#
# --------------------------
# INFO:  day is :  2025-12-05 15:00:00.000
# --------------------------
# INFO:  Checking that Sp0900+2150 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_r_instrument_system_response.csv` has been generated and saved!
# total_hours 177.19555555555556 h texp 49.0 s
# INFO:  Checking that Sp0011+5908 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 212.21222222222224 h texp 13.0 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp0109+2949 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 148.02555555555557 h texp 112.80463839127474 s
# INFO:  First target is 'rise'
#
#
# --------------------------
# INFO:  day is :  2025-12-06 15:00:00.000
# --------------------------
# INFO:  Checking that Sp0011+5908 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours 212.21222222222224 h texp 13.0 s
# WARNING:  this first target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp0330+5413 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours 102.36 h texp 15.0 s
# INFO:  Checking that Sp0228+1639 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 108.27208726011642 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0144-0716 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 434.0246135998258 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0019+5213 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 160.62444444444444 h texp 82.88843814284216 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0015+3516 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 355.24694679052385 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0217+3526 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 10.0 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0246+1625 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 50.48 h texp 14.759096777673784 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0314+2840 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 126.5 h texp 12.00692661521057 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp1022+5825 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 190.26198283386466 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0158+1807 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 45.6 h texp 32.4747312225293 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0020+3305 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 90.886 h texp 14.0 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0253+2713 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 90.42 h texp 51.19497612793015 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0911+7401 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 80.77 h texp 79.61179629407545 s
# INFO:  Checking that Sp0841+5929 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_r_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 88.81 h texp 13.0 s
# INFO:  Checking that Sp0219+5912 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 119.04 h texp 15.45283138399101 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0213+4444 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 210.45071186228154 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp0859+6341 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 215.87095185154342 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp0632+8305 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 11.84 h texp 225.37172291444003 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0151+6423 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 57.5 h texp 165.0595411353121 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0141+1804 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 243.79457646803618 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0208+2542 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 269.75665987243065 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0107+2435 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 129.1146473555072 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0233+2209 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 77.63984531340546 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0130-0211 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 96.11201886368062 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0624+6626 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 195.0586538608182 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0103+4509 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 223.7574398420667 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp0851+7727 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 71.48890849084493 s
# INFO:  Checking that Sp0241+5444 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 129.926178466794 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0125+2847 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 99.20039340028461 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0921+6017 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 100.01863206961933 s
# INFO:  Checking that Sp0243+4755 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 66.23905169346153 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp2112+8427 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 93.42617364762226 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0840+5911 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 90.06778782633609 s
# INFO:  Checking that Sp0334+3740 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 45.95861072205006 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0044+5610 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 86.04480283302436 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0212+2433 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 109.84026678710782 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0128+0211 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 62.84419026186721 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp1002+6349 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 84.34645660240139 s
# INFO:  Checking that Sp0857+5708 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 799.4876590492232 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp2357+5727 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 140.6356387390058 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0341+4741 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 115.68790431741068 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0234+6012 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 300.85041942844094 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0130+1721 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 256.06677206463013 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0135+1205 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 472.09022716224865 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp1021+5055 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 115.29254504381704 s
# INFO:  Checking that Sp0315+8122 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 12.6 h texp 81.44705031843198 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp2259+8013 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 165.44568944876522 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0330+3146 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 123.0577822023689 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0124+8334 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 116.73467973958026 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0155+0950 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 699.7357305182459 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0004+5843 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 162.1784097801497 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0257+4111 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 295.4612227520801 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0059+5726 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 71.23294770044525 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0307+5719 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 204.36672452344925 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp1011+4245 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 107.45506246812039 s
# INFO:  Checking that Sp0008+5453 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 123.9870189593238 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0126+1419 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 80.6911512459826 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0043+2426 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 195.28406344708878 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0053+4942 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 84.33166860270839 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp2333+7456 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 112.09032889246353 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0823+6125 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 52.1 h texp 717.2111814896947 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0202+7053 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 113.40430538400429 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0611+6818 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 95.3662052532363 s
# INFO:  First target is 'set'
#
#
# --------------------------
# INFO:  day is :  2025-12-07 15:00:00.000
# --------------------------
# INFO:  Checking that Sp0011+5908 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours 212.21222222222224 h texp 13.0 s
# WARNING:  this first target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp0330+5413 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours 108.62388888888889 h texp 15.0 s
# INFO:  Checking that Sp0228+1639 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 108.27208726011642 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0144-0716 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 434.0246135998258 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0019+5213 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 160.62444444444444 h texp 82.88843814284216 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0015+3516 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 355.24694679052385 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# WARNING:  no second target available
# INFO:  Checking that Sp0217+3526 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_z_instrument_system_response.csv` has been generated and saved!
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_i_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 10.0 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0246+1625 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 50.48 h texp 14.759096777673784 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp0314+2840 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 126.5 h texp 12.00692661521057 s
# WARNING:  finding another second target that respects the constraints
# INFO:  Checking that Sp1022+5825 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 0.0 h texp 190.26198283386466 s
# WARNING:  this second target will exceed 200 hours observed or has texp>180s, looking for the next one
# INFO:  Checking that Sp0551+5511 does not exceed max hours
# INFO:mphot.core:`/Users/ed268546/mphot/src/mphot/datafiles/system_responses/speculoos_Andor_iKon-L-936_-60_I+z_instrument_system_response.csv` has been generated and saved!
# total_hours second target of the night 119.11 h texp 23.19667761512666 s
# INFO:  First target is 'set'
#
#
# --------------------------
# INFO:  day is :  2025-12-08 15:00:00.000
# --------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hq/0cjvstf11cqbtmz26c9stns82w1k7g/T/ipykernel_15564/2665317336.py in ?()
#      17     else:
#      18         schedule.telescope = schedule.observatory_name
#      19     if schedule.observatory_name == 'Saint-Ex':
#      20         schedule.telescope = 'Saint-Ex'
# ---> 21         schedule.make_schedule(Altitude_constraint = 28, Moon_constraint = 30)
#      22         display(schedule.target_table_spc[schedule.idx_first_target])
#      23         display(schedule.target_table_spc[schedule.idx_second_target])
#      24         display(Javascript('Jupyter.notebook.execute_cells([13])'))
#
# ~/Dropbox/Mac/Documents/codes/SPOCK_v2/SPOCK/long_term_scheduler.py in ?(self, Altitude_constraint, Moon_constraint)
#    1262         self.night_duration = self.end_night - self.start_night
#    1263         # dura = Time(Time(self.observatory.twilight_morning_nautical(day + dt_1day ,which='nearest')).jd - \
#    1264         # Time(self.observatory.twilight_evening_nautical(day ,which='next')).jd,format='jd')
#    1265         # return dura
#
# ~/Dropbox/Mac/Documents/codes/SPOCK_v2/SPOCK/long_term_scheduler.py in ?(self, day)
#    1660                 if set_first_target < self.observatory.target_rise_time(self.date_range[0] + t,
#    1661                                                             self.selected_first_target,
#    1662                                                             which='nearest',
#    1663                                                             horizon=self.Altitude_constraint * u.deg):  # typically happens for Saint-Ex as the night start in the middle of a UTC time night
# -> 1664
#    1665                     set_first_target = self.observatory.target_set_time(self.date_range[0] + t + 1,
#    1666                                                                         self.selected_first_target,
#    1667                                                                         which='next',
#
# ~/env_SPOCKv2/lib/python3.12/site-packages/astropy/coordinates/sky_coordinate.py in ?(self, frame, merge_attributes)
#     551         generic_frame = GenericFrame(frame_kwargs)
#     552
#     553         # Do the transformation, returning a coordinate frame of the desired
#     554         # final type (not generic).
# --> 555         new_coord = trans(self.frame, generic_frame)
#     556
#     557         # Finally make the new SkyCoord object from the `new_coord` and
#     558         # remaining frame_kwargs that are not frame_attributes in `new_coord`.
#
# ~/env_SPOCKv2/lib/python3.12/site-packages/astropy/coordinates/transformations/composite.py in ?(self, fromcoord, toframe)
#     109                     attr = getattr(fromcoord, inter_frame_attr_nm)
#     110                     frattrs[inter_frame_attr_nm] = attr
#     111
#     112             curr_toframe = t.tosys(**frattrs)
# --> 113             curr_coord = t(curr_coord, curr_toframe)
#     114
#     115         # this is safe even in the case where self.transforms is empty, because
#     116         # coordinate objects are immutable, so copying is not needed
#
# ~/env_SPOCKv2/lib/python3.12/site-packages/astropy/coordinates/transformations/function.py in ?(self, fromcoord, toframe)
#     171         )
#     172
#     173         supcall = self.func
#     174         if not fromcoord.data.differentials:
# --> 175             return supcall(fromcoord, toframe)
#     176         # this is the finite difference case
#     177
#     178         if callable(self.finite_difference_dt):
#
# ~/env_SPOCKv2/lib/python3.12/site-packages/astropy/coordinates/builtin_frames/icrs_observed_transforms.py in ?(icrs_coo, observed_frame)
#      31         isinstance(icrs_coo.data, UnitSphericalRepresentation)
#      32         or icrs_coo.cartesian.x.unit == u.one
#      33     )
#      34     # first set up the astrometry context for ICRS<->observed
# ---> 35     astrom = erfa_astrom.get().apco(observed_frame)
#      36
#      37     # correct for parallax to find BCRS direction from observer (as in erfa.pmpx)
#      38     if is_unitspherical:
#
# ~/env_SPOCKv2/lib/python3.12/site-packages/astropy/coordinates/erfa_astrom.py in ?(frame_or_coord)
#      52
#      53         jd1_tt, jd2_tt = get_jd12(obstime, "tt")
#      54         xp, yp = get_polar_motion(obstime)
#      55         sp = erfa.sp00(jd1_tt, jd2_tt)
# ---> 56         x, y, s = get_cip(jd1_tt, jd2_tt)
#      57         era = erfa.era00(*get_jd12(obstime, "ut1"))
#      58         earth_pv, earth_heliocentric = prepare_earth_position_vel(obstime)
#      59
#
# ~/env_SPOCKv2/lib/python3.12/site-packages/astropy/coordinates/builtin_frames/utils.py in ?(jd1, jd2)
#     161     rpnb = erfa.pnm06a(jd1, jd2)
#     162     # CIP X, Y coordinates from array
#     163     x, y = erfa.bpn2xy(rpnb)
#     164     # CIO locator, s
# --> 165     s = erfa.s06(jd1, jd2, x, y)
#     166     return x, y, s
#
# ~/env_SPOCKv2/lib/python3.12/site-packages/erfa/core.py in ?(date1, date2, x, y)
#   11814         Copyright (C) 2013-2023, NumFOCUS Foundation.
#   11815         Derived, with permission, from the SOFA library.  See notes at end of file.
#   11816
#   11817     """
# > 11818     c_retval = ufunc.s06(date1, date2, x, y)
#   11819     return c_retval
#
# KeyboardInterrupt:

# %%
# CELL 4 -- Lock block for future obs
lock_target_widget = widgets.Button(
    value=False,
    description='Lock block',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Save',
    icon='check'
)
def run_lock(b): 
    schedule.locking_observations()

display(lock_target_widget)

lock_target_widget.on_click(run_lock)

# %%
# CELL 5 -- Plot visibility plot
@interact
def plt_target(site=['Saint-Ex','SSO','SNO','TS_La_Silla','TN_Oukaimeden'],\
               Target=list(pd.read_csv(target_list_from_stargate_path,delimiter=',')['Sp_ID']),\
               day_widget = widgets.DatePicker(description='Pick a Date')):
    try:
        day = Time(datetime.datetime.combine(day_widget,datetime.time(15,0,0)),format='datetime')
        SPOCKplot.airmass_altitude_plot_given_target(name_observatory=site,\
                                                     day=day,\
                                                     target=Target,\
                                                     path_target_list=target_list_from_stargate_path)

    except TypeError:
        print(Fore.RED + 'ERROR:  ' + Fore.BLACK + ' Choose a date or wait for the plot to load. ')

# %%
# CELL 6 -- Plot gant chart
@interact
def plt_gant_chart(Telescope=['Europa','Io','Callisto','Ganymede','Artemis','Saint-Ex','TS_La_Silla','TN_Oukaimeden','all_speculoos'],start_widget = widgets.DatePicker(description='Start Date'),end_widget = widgets.DatePicker(description='End Date')):
    try:
        start_day = Time(datetime.datetime.combine(start_widget,datetime.time(15,0,0)),format='datetime')
        end_day = Time(datetime.datetime.combine(end_widget,datetime.time(15,0,0)),format='datetime')
        if Telescope == 'all_speculoos':
            Telescope = ['Europa','Io','Callisto','Ganymede','Artemis', 'Saint-Ex']
        SPOCKplot.gantt_chart(start_day,end_day,Telescope)
    except (TypeError,NameError) as e:
        print(Fore.RED + 'ERROR:  ' + Fore.BLACK +' Choose date range ! '),

# %%
# CELL 7 -- BUTTON -- Save plans
save_widget = widgets.Button(
    value=False,
    description='Save plans',
    layout=Layout(width='20%', height='40px'),
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    style= {'button_color':'palegoldenrod'},
    tooltip='Save',
    icon='check'
)
def run_save(b): 
    display(Javascript('Jupyter.notebook.execute_cells([8])'))

display(save_widget)

save_widget.on_click(run_save)

# %%
# CELL 8 -- Save Plans
start_date = Time(datetime.datetime.strptime(str(start_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
end_date = Time(datetime.datetime.strptime(str(end_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
schedule = SPOCKLT.Schedules()
schedule.observatory_name = observatory_widget.value
schedule.load_parameters(date_range=[start_date,end_date])
schedule.date_range = Time([start_date,end_date])

if tab_nest.selected_index == 0:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)
        
    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)
        
    if schedule.observatory.name == 'SSO':
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)

    if schedule.observatory.name == 'TS_La_Silla':
        schedule.telescope = 'TS_La_Silla'
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)
        
    if schedule.observatory.name == 'TN_Oukaimeden':
        schedule.telescope = 'TN_Oukaimeden'
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)

if tab_nest.selected_index == 1:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)

    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)
          
    if schedule.observatory.name == 'SSO':
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)
         
    if schedule.observatory.name == 'TS_La_Silla':
        schedule.telescope = 'TS_La_Silla'
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)
        
    if schedule.observatory.name == 'TN_Oukaimeden':
        schedule.telescope = 'TN_Oukaimeden'
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)

# %%
# CELL 9 -- BUTTON -- Make plans
makeplans_widget = widgets.Button(
    value=False,
    description='Make ACP plans',
    layout=Layout(width='20%', height='40px'),
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    style= {'button_color':'palegreen'},
    tooltip='Make',
    icon='check'
)
def run_make(b): 
    display(Javascript('Jupyter.notebook.execute_cells([10])'))

display(makeplans_widget)

makeplans_widget.on_click(run_make)

# %%
# CELL 10 -- Make plans
start_date = Time(datetime.datetime.strptime(str(start_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
end_date = Time(datetime.datetime.strptime(str(end_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
schedule = SPOCKLT.Schedules()
schedule.observatory_name = observatory_widget.value
schedule.load_parameters(date_range=[start_date,end_date])
schedule.date_range = Time([start_date,end_date])

if tab_nest.selected_index == 0:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)

    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)

    if schedule.observatory.name == 'SSO':
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
    display(Javascript('Jupyter.notebook.execute_cells([11])'))

if tab_nest.selected_index == 1:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        SPOCKST.make_plans(day=schedule.day_of_night, nb_days=1, fs
                           telescope=schedule.telescope)
        
    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKST.make_plans(day=schedule.day_of_night, nb_days=1, 
                           telescope=schedule.telescope)
        
    if schedule.observatory.name == 'SSO':
        SPOCKST.make_plans(day=schedule.day_of_night, nb_days=1, 
                           telescope=schedule.telescope)
    display(Javascript('Jupyter.notebook.execute_cells([11])'))
        
if tab_nest.selected_index == 3:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        
    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)

    if schedule.observatory.name == 'SSO':
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        
    if schedule.observatory.name == 'TS_La_Silla':
        schedule.telescope = 'TS_La_Silla'
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        
    if schedule.observatory.name == 'TN_Oukaimeden':
        schedule.telescope = 'TN_Oukaimeden'
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
    display(Javascript('Jupyter.notebook.execute_cells([11])'))

# %%
# CELL 11 -- BUTTON -- Upload plans
uploadplans_widget = widgets.Button(
    value=False,
    description='Upload ACP plans/night-blocks',
    layout=Layout(width='30%', height='40px'),
    
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    style= {'button_color':'lightblue'},
    tooltip='Upload',
    icon='check'
)
def run_upload(b): 
    display(Javascript('Jupyter.notebook.execute_cells([12])'))

display(uploadplans_widget)

uploadplans_widget.on_click(run_upload)

# %%
# CELL 12 -- Upload plans
start_date = Time(datetime.datetime.strptime(str(start_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
end_date = Time(datetime.datetime.strptime(str(end_date_widget.value), '%Y-%m-%d')+datetime.timedelta(hours=15)).iso
schedule = SPOCKLT.Schedules()
schedule.observatory_name = observatory_widget.value
schedule.load_parameters(date_range=[start_date,end_date])
schedule.date_range = Time([start_date,end_date])

if tab_nest.selected_index == 0:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)
        
    if schedule.observatory.name == 'SSO':
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)
if tab_nest.selected_index == 1:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        R
        
    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKST.upload_plans(day=schedule.day_of_night, nb_days=1,
                             telescope = schedule.telescope)
       
        
    if schedule.observatory.name == 'SSO':
        SPOCKST.upload_plans(day=schedule.day_of_night, nb_days=1,
                             telescope = schedule.telescope)
        
if tab_nest.selected_index == 3:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)
        
    if schedule.observatory.name == 'SSO':
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

    if schedule.observatory.name == 'TS_La_Silla':
        schedule.telescope = 'TS_La_Silla'
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)
        
    if schedule.observatory.name == 'TN_Oukaimeden':
        schedule.telescope = 'TN_Oukaimeden'
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

# %%
# CELL 13 -- BUTTON -- Save plans, Make plans, Upload plans
smu_plans_widget = widgets.Button(
    value=False,
    description='Save, make, upload',
    layout=Layout(width='20%', height='40px'),
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='',
    icon='check'
)
def run_savemakeupload(b): 
    display(Javascript('Jupyter.notebook.execute_cells([14])'))

display(smu_plans_widget)

smu_plans_widget.on_click(run_savemakeupload)

# %%
# CELL 14 -- Save Plans, Make plans, and Upload plans
if tab_nest.selected_index == 0:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)
        offset_target_position(day_start=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                               telescope=schedule.telescope,ra_offset=15, dec_offset=15)
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)
        
    if schedule.observatory.name == 'SSO':
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

    if schedule.observatory.name == 'TS_La_Silla':
        schedule.telescope = 'TS_La_Silla'
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)
        display(Javascript("Jupyter.notebook.execute_cells([9])"))
        
    if schedule.observatory.name == 'TN_Oukaimeden':
        schedule.telescope = 'TN_Oukaimeden'
        SPOCKLT.save_schedule(save=True, over_write=True, date_range=schedule.date_range, 
                              telescope=schedule.telescope)
        display(Javascript("Jupyter.notebook.execute_cells([9])"))

if tab_nest.selected_index == 1:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)
        offset_target_position(day_start=schedule.day_of_night, nb_days=1,
                               telescope=schedule.telescope,ra_offset=15, dec_offset=15)
        SPOCKST.make_plans(day=schedule.day_of_night, nb_days=1, 
                           telescope=schedule.telescope)
        SPOCKST.upload_plans(day=schedule.day_of_night, nb_days=1,
                             telescope = schedule.telescope)
        
    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)
        SPOCKST.make_plans(day=schedule.day_of_night, nb_days=1, 
                           telescope=schedule.telescope)
        SPOCKST.upload_plans(day=schedule.day_of_night, nb_days=1,
                             telescope = schedule.telescope)
       
        
    if schedule.observatory.name == 'SSO':
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)
        SPOCKST.make_plans(day=schedule.day_of_night, nb_days=1, 
                           telescope=schedule.telescope)
        SPOCKST.upload_plans(day=schedule.day_of_night, nb_days=1,
                             telescope = schedule.telescope)
         
    if schedule.observatory.name == 'TS_La_Silla':
        schedule.telescope = 'TS_La_Silla'
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)
        display(Javascript("Jupyter.notebook.execute_cells([9])"))
        
    if schedule.observatory.name == 'TN_Oukaimeden':
        schedule.telescope = 'TN_Oukaimeden'
        SPOCKST.save_schedule(save=True, over_write=True, day=schedule.day_of_night, 
                              telescope=schedule.telescope)
        display(Javascript("Jupyter.notebook.execute_cells([9])"))
        
if tab_nest.selected_index == 3:
    schedule.telescope = telescope_widget.value
    if schedule.observatory.name == 'SNO':
        schedule.telescope = 'Artemis'
        offset_target_position(day_start=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                               telescope=schedule.telescope,ra_offset=15, dec_offset=15)
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

    if schedule.observatory.name == 'Saint-Ex':
        schedule.telescope = 'Saint-Ex'
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)
        
    if schedule.observatory.name == 'SSO':
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        #time.sleep(5) 
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

    if schedule.observatory.name == 'TS_La_Silla':
        schedule.telescope = 'TS_La_Silla'
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)
        
    if schedule.observatory.name == 'TN_Oukaimeden':
        schedule.telescope = 'TN_Oukaimeden'
        SPOCKLT.make_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days, 
                           telescope=schedule.telescope)
        SPOCKLT.upload_plans(day=schedule.date_range[0], nb_days=schedule.date_range_in_days,
                             telescope = schedule.telescope)

# %%
# Cell 15 -- BUTTON -- Make schedule for TS and TN (docx files)

docx_widget = widgets.Button(
    value=False,
    description='Update .docx file',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Docx',
    icon='check'
)
start_date_docx_widget =widgets.DatePicker(
    description='Start .docx',
    disabled=False)

end_date_docx_widget =widgets.DatePicker(
    description='End .docx',
    disabled=False)

def run_save(b): 
    display(Javascript('Jupyter.notebook.execute_cells([9])'))
    
    
docx = widgets.Accordion(children=[widgets.HBox([start_date_docx_widget,end_date_docx_widget,docx_widget])])

display(docx)

docx_widget.on_click(run_save)

# %%
# Cell 16 -- Make schedule for TS and TN (docx files)
schedule = SPOCKLT.Schedules()
schedule.observatory = observatory_widget.value
schedule.telescope = observatory_widget.value
start_date = Time(datetime.datetime.strptime(str(start_date_docx_widget.value), '%Y-%m-%d')+
                  datetime.timedelta(hours=15)).iso
end_date = Time(datetime.datetime.strptime(str(end_date_docx_widget.value), '%Y-%m-%d')+
                datetime.timedelta(hours=15)).iso
schedule.date_range = Time([start_date,end_date])
SPOCKLT.make_docx_schedule(observatory_name=schedule.observatory,telescope=schedule.telescope,
                           date_range=schedule.date_range, name_operator=operator_widget.value)

# %%
# Cell 17 -- Plot phase coverage SPECULOOS targets
@interact
def plt_phase_cov(Target=pd.concat([pd.read_csv(target_list_from_stargate_path,
                                          delimiter=',')['Sp_ID'], 
                                    schedules_st.target_table_spc_follow_up['Sp_ID']]),
                  periods = widgets.FloatRangeSlider(value=[0, 6],min=0,max=20.0,step=0.1,
                                                     description='Period range:', disabled=False,
                                                     continuous_update=True,orientation='horizontal',
                                                     readout=True,readout_format='.1f',)):
    schedule = SPOCKLT.Schedules()
    schedule.observatory_name = "SSO"
    schedule.load_parameters()
    
    try: 
        SPOCKplot.phase_coverage_given_target(target=Target,pmin=periods[0],pmax=periods[1])
    except ValueError:
        print(Fore.RED + 'ERROR:  ' + Fore.BLACK + ' No data for this target ! ')

# %%
# Cell 18 -- Read night plans
@interact
def night_block(telescope=['Saint-Ex','Io','Europa','Ganymede','Callisto','Artemis','TS_La_Silla','TN_Oukaimeden'],day_widget = widgets.DatePicker(description='Pick a Date')):
    try:
        day = Time(datetime.datetime.combine(day_widget,datetime.time(15,0,0))).iso
        date = Time(day,out_subfmt='date').iso
        nightp = SPOCKstats.read_night_plans_server(telescope,date)
        if nightp.columns[0] == '<!DOCTYPE':
            print(Fore.RED + 'ERROR:  ' + Fore.BLACK +' No night plan on this date ! ')
        else: 
            display(nightp)
    except TypeError:
        print(Fore.RED + 'ERROR:  ' + Fore.BLACK + ' Choose a date or wait for the plot to load. ')

# %%
# Cell 19 -- Show Info targets
@interact
def plt_target(Target=list(pd.read_csv(target_list_from_stargate_path,delimiter=',')['Sp_ID'])):
    target_list = pd.read_csv(target_list_from_stargate_path,sep=',')
    target_list.drop(['fc_url','Unnamed: 42','phot_spt_ref','phot_spt','spec_spt','spec_spt_ref','telescope'],axis='columns',inplace=True)
    a = target_list.where((target_list['Sp_ID']==Target))
    a['Gaia_ID'] = a['Gaia_ID'].map('{:.2f}'.format)
    a  = a.dropna()
    idx_gaia_id = np.where((target_list['Sp_ID']==Target))[0]
    a['Gaia_ID'] = int(target_list["Gaia_ID"][idx_gaia_id])
    display(a)
    #try:
    #    day = Time(datetime.datetime.combine(day_widget,datetime.time(15,0,0)),format='datetime')
    #    SPOCKstats.read_night_plans_server(telescope,date)
#
    #except TypeError:                                                                                
    #    print(Fore.RED + 'ERROR:  ' + Fore.BLACK +' Choose a date ! ')

# %%
# Cell 20 -- Predict transit windows from WG6
@interact
def predictions(Target=list(schedules_st.target_table_spc_follow_up['Sp_ID']),
                day_widget = widgets.DatePicker(description='Pick a Date'),
                nb_transits=widgets.IntSlider(min=1, max=30, step=1, value=10)):
    if day_widget is not None:
        if Target:
            day = Time(datetime.datetime.combine(day_widget,datetime.time(15,0,0))).iso
            ra,dec,timing,period,duration = SPOCKST.get_info_follow_up_target(Target,
                                                target_list_follow_up=schedules_st.target_table_spc_follow_up)
            table_prediction = SPOCKST.prediction(name=Target,ra=ra,dec=dec,
                               timing=timing,
                               period=period,duration=duration,
                               start_date=day,ntr=nb_transits)
            display(table_prediction)
        else:
            sys.exit(Fore.YELLOW + 'WARNING:' + Fore.BLACK + ' If you don\'t select a target you must enter the info in the next tab')
    else:
        pass

# %%
# Cell 21 -- Predict transit windows from ephemeris
day = Time(datetime.datetime.combine(prediction_date_widget.value,datetime.time(15,0,0))).iso
table_prediction = SPOCKST.prediction(name=name_widget.value,ra=ra_text.value,dec=dec_text.value,
                               timing=timing_text.value,
                               period=period_text.value,duration=duration_text.value,
                               start_date=day,ntr=nb_transits_widget.value)
display(table_prediction)

# %%
# CELL 22 -- Plot visibility plot target follow-up
@interact
def plt_target(site=['Saint-Ex','SSO','SNO','TS_La_Silla','TN_Oukaimeden'],\
               target=schedules_st.target_table_spc_follow_up['Sp_ID'],\
               day_widget = widgets.DatePicker(description='Pick a Date')):
    
    schedules_st = SPOCKST.Schedules() 
    schedules_st.load_parameters()
    idx = np.where((schedules_st.target_table_spc_follow_up['Sp_ID'] == target))[0]
    try:
        day = Time(datetime.datetime.combine(day_widget,datetime.time(15,0,0)),format='datetime')
        SPOCKplot.airmass_altitude_plot_nolist(name_observatory=site, day=day, 
                                               target = target, 
                                               ra = schedules_st.target_table_spc_follow_up['RA'][idx], 
                                               dec = schedules_st.target_table_spc_follow_up['DEC'][idx])
        
    except TypeError:
        print(Fore.RED + 'ERROR:  ' + Fore.BLACK + ' Choose a date or wait for the plot to load. ')

# %%
# CELL 23 -- Plot visibility plot target special
@interact
def plt_target(site=['Saint-Ex','SSO','SNO','TS_La_Silla','TN_Oukaimeden'],\
               target=schedules_st.target_table_spc['Sp_ID'],\
               day_widget = widgets.DatePicker(description='Pick a Date')):
    
    schedules_st = SPOCKST.Schedules() 
    schedules_st.load_parameters()
    idx = np.where((schedules_st.target_table_spc['Sp_ID'] == target))[0]
    try:
        day = Time(datetime.datetime.combine(day_widget,datetime.time(15,0,0)),format='datetime')
        SPOCKplot.airmass_altitude_plot_nolist(name_observatory=site, day=day, 
                                               target = target, 
                                               ra = schedules_st.target_table_spc['RA'][idx], 
                                               dec = schedules_st.target_table_spc['DEC'][idx])
        
    except TypeError:
        print(Fore.RED + 'ERROR:  ' + Fore.BLACK + 'Choose a date or wait for the plot to load. ')

# %%
# Cell 24 -- Predict transit windows from WG6 for MANGOs candidates
@interact
def predictions_mangos(Target=list(schedules_mangos.target_table_spc_follow_up['Sp_ID']),
                day_widget = widgets.DatePicker(description='Pick a Date'),
                nb_transits=widgets.IntSlider(min=1, max=30, step=1, value=10)):
    if day_widget is not None:
        if Target:
            day = Time(datetime.datetime.combine(day_widget,datetime.time(15,0,0))).iso
            ra,dec,timing,period,duration = SPOCKST.get_info_follow_up_target(Target,
                                                target_list_follow_up=schedules_mangos.target_table_spc_follow_up)
            table_prediction = SPOCKST.prediction(name=Target,ra=ra,dec=dec,
                               timing=timing,
                               period=period,duration=duration,
                               start_date=day,ntr=nb_transits)
            display(table_prediction)
        else:
            sys.exit(Fore.YELLOW + 'WARNING:  ' + Fore.BLACK + ' If you don\'t select a target you must enter the info in the next tab')
    else:
        pass
